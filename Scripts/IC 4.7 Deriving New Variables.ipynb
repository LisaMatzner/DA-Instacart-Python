# %% [markdown]
# # 4.7 Deriving New Variables

# %% [markdown]
# ### This notebook contains:
#     01. Importing Libraries
#     02. Importing Data
#     03. Deriving New Variables - Exercise
#         A. If-Statements with User-Defined Functions
#         B. If-Statements with the loc() Function
#         C. If-Statements with For-Loops
#     04. Deriving New Variables - Task

# %% [markdown]
# ## 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 02. Improting Data

# %%
# turning project folder path into string
path = r'/Users/lisa/DA Projects/12-2022 Instacart Basket Analysis'

# %%
# Importing merged orders and prods data
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ## 03. Deriving New Variables - Exercise

# %%
# creating subset for dataset
df = ords_prods_merged[:1000000]

# %% [markdown]
# ### A. If-Statements with User-Defined Functions

# %%
# define Function for Price Labels
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# using function on dataframe
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/nw/3x195xtd1_qbx98wtb2nk6t40000gn/T/ipykernel_20734/851938743.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# checking frequency
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# looking for most expensive product
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# #### Summary
# Used when reusability is high priority and you want to use specific logic that's not available in built-in Python functions.
# Runs slower than loc() function and can take a lot of processing power.
# Can return error messages.

# %% [markdown]
# ###  B. If-Statements with the loc() Function

# %%
# Condition high-range product
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/nw/3x195xtd1_qbx98wtb2nk6t40000gn/T/ipykernel_20734/2507851992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# Condition mid-range product
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# Condition low-range product
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# checking frequency
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# #### Labeling whole ords prods dataframe

# %%
# Condition high-range product
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
# Condition mid-range product
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
# Condition low-range product
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# checking frequency
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21104410
# Low-range product     10126321
# Mid-range product       756450
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# #### Summary
# Used to apply the conditional logic of an if-statement to a function without explicitly creating an if-else construct. Good for filtering operations.
# Faster than a user-defined function. Preferable for large dataframes.

# %% [markdown]
# ### C. If-Statements with For-Loops

# %%
ords_prods_merged.head(0)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, first_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge, price_range_loc]
# Index: []

# %%
# Checking frequency for order day of the week
ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %%
# creating for-loop for daily order activity
result = []

for value in ords_prods_merged["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  ...]

# %%
# Combining results with ords prods merged
ords_prods_merged['busiest_day'] = result

# %%
# frequency check
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# #### Summary
# Runs the same block of code for multiple items. They’re used to perform the same function on multiple elements, for instance, by running through an entire dataframe and performing a function on each row within that dataframe.
# Speeds up performance as the function only runs through one column (as specified in code) instead of the whole dataframe.

# %% [markdown]
# ## 04. Deriving New Variables - Task

# %%
# Getting Overview 
ords_prods_merged.head(0)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, first_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge, price_range_loc, busiest_day]
# Index: []

# %% [markdown]
# ##### 2.Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# Checking frequency for order day of the week
ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %% [markdown]
# The two busiest days are Saturday (0) and Sunday (1). The two least busy days are Wednesday (4) and Tuesday (3).
# Friday (6), Monday (2) and Thursday (5) are "Regularly busy".

# %%
# creating for-loop for daily order activity
result2 = []

for value in ords_prods_merged["order_day_of_week"]:
  if value == 0 or value == 1:
    result2.append("Busy day")
  elif value == 4 or value == 3:
    result2.append("Less busy")
  else:
    result2.append("Regularly busy")

# %%
result2
# Out:
# ['Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Regularly busy',
#  'Less busy',
#  'Less busy',
#  'Less busy',
#  'Busy day',
#  'Regularly busy',
#  'Less busy',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Busy day',
#  'Less busy',
#  'Busy day',
#  ...]

# %%
# Combining results with ords prods merged
ords_prods_merged['busiest_days'] = result2

# %% [markdown]
# ##### 3.Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# frequency check
ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busy day          11864412
# Less busy          7624336
# Name: busiest_days, dtype: int64

# %%
# check 2: calculating order days of week
print(6204182+5660230) 
print('busy days')
print(3783802+3840534)
print('less busy')
print(4496490+4213830+4205791)
print('reg busy')
# Out:
# 11864412
# busy days
# 7624336
# less busy
# 12916111
# reg busy

# %%
# checking column headers
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                    15.0        False         196                  1
# 2                    21.0        False         196                  1
# 3                    29.0        False         196                  1
# 4                    28.0        False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0          0         Soda        77              7     9.0   both
# 1          1         Soda        77              7     9.0   both
# 2          1         Soda        77              7     9.0   both
# 3          1         Soda        77              7     9.0   both
# 4          1         Soda        77              7     9.0   both
#
#      price_range_loc     busiest_day    busiest_days
# 0  Mid-range product  Regularly busy  Regularly busy
# 1  Mid-range product  Regularly busy       Less busy
# 2  Mid-range product  Regularly busy       Less busy
# 3  Mid-range product      Least busy       Less busy
# 4  Mid-range product      Least busy       Less busy

# %% [markdown]
# I decided to leave the busiest_day varibale in the dataframe.

# %% [markdown]
# ##### 4.When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.”

# %%
# checking frequency in order hour of day per hour
ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# I decided to categorize the time ranges by determining the quartiles. All order hours frequencies over 75% of all orders will be hours with "Most orders". All hours in between 75% and 50% are "Average orders" and everything below 50% will be "Fewest orders".

# %%
# Calculating quartiles
(ords_prods_merged['order_hour_of_day'].value_counts(dropna = False).quantile([0.25,0.5,0.75]))
# Out:
# 0.25     272562.0
# 0.50    1117230.5
# 0.75    2556034.5
# Name: order_hour_of_day, dtype: float64

# %% [markdown]
# #### Results:
#     Most orders: 10,11,12,13,14,15
#     Average orders: 8,9,16,17,18,19
#     Fewest orders: 0,1,2,3,4,5

# %%
# creating for-loop for busiest time periods
result3 = []

for value in ords_prods_merged["order_hour_of_day"]:
  if value <= 5:
    result3.append("Fewest orders")
  elif value >= 10:
    result3.append("Most orders")
  else:
    result3.append("Average orders")

# %%
result3
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  ...]

# %%
# Combining results with ords prods merged
ords_prods_merged['busiest_period_of_day'] = result3

# %%
# check header
ords_prods_merged.head(0)
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_prior_order, first_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, _merge, price_range_loc, busiest_day, busiest_days, busiest_period_of_day]
# Index: []

# %% [markdown]
# ##### 5.Print the frequency for this new column.

# %%
# Checking frequency
ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       26454663
# Average orders     5353868
# Fewest orders       596328
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ##### 7.Export your dataframe as a pickle file (since you added new columns) and store it correctly in your “Prepared Data” folder.

# %%
# Exporting merged ords as PKL
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_flagged.pkl'))
